# %% [markdown]
# # Basic Time Series Models - Lab

# %% [markdown]
# ## Introduction
#
# Now that you have an initial understanding of the the White Noise and the Random Walk model, let's try to generate some examples!

# %% [markdown]
# ## Objectives
#
# You will be able to:
# - Explain what the goal is of time series modeling
# - Understand and explain what a White Noise model is
# - Understand and explain what a Random Walk model is
# - Understand the mathematical formulations of Random Walk and White Noise models

# %% [markdown]
# ## A White Noise Model

# %% [markdown]
# To get a good sense of how a model works, it is always a good idea to generate a process. Let's consider the following example:
# - Every day in August, September and October 2018, Nina takes the subway to work. Let's ignore weekends for now and assume that Nina works every day.
# - We know that on average, it takes her 25 minutes, and the standard deviation is 4 minutes.
# - Create and visualize a time series that reflects this information.

# %% [markdown]
# Let's import pandas, numpy and matplotlib.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(12) # do not change this seed.

# %% [markdown]
# Create the dates. You can do this using `pd.date_range`, more info [here](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.date_range.html).

# %%
dates = pd.date_range(start='2018-08-01', end='2018-10-31', name='date')
dates
# Out:
# DatetimeIndex(['2018-08-01', '2018-08-02', '2018-08-03', '2018-08-04',
#                '2018-08-05', '2018-08-06', '2018-08-07', '2018-08-08',
#                '2018-08-09', '2018-08-10', '2018-08-11', '2018-08-12',
#                '2018-08-13', '2018-08-14', '2018-08-15', '2018-08-16',
#                '2018-08-17', '2018-08-18', '2018-08-19', '2018-08-20',
#                '2018-08-21', '2018-08-22', '2018-08-23', '2018-08-24',
#                '2018-08-25', '2018-08-26', '2018-08-27', '2018-08-28',
#                '2018-08-29', '2018-08-30', '2018-08-31', '2018-09-01',
#                '2018-09-02', '2018-09-03', '2018-09-04', '2018-09-05',
#                '2018-09-06', '2018-09-07', '2018-09-08', '2018-09-09',
#                '2018-09-10', '2018-09-11', '2018-09-12', '2018-09-13',
#                '2018-09-14', '2018-09-15', '2018-09-16', '2018-09-17',
#                '2018-09-18', '2018-09-19', '2018-09-20', '2018-09-21',
#                '2018-09-22', '2018-09-23', '2018-09-24', '2018-09-25',
#                '2018-09-26', '2018-09-27', '2018-09-28', '2018-09-29',
#                '2018-09-30', '2018-10-01', '2018-10-02', '2018-10-03',
#                '2018-10-04', '2018-10-05', '2018-10-06', '2018-10-07',
#                '2018-10-08', '2018-10-09', '2018-10-10', '2018-10-11',
#                '2018-10-12', '2018-10-13', '2018-10-14', '2018-10-15',
#                '2018-10-16', '2018-10-17', '2018-10-18', '2018-10-19',
#                '2018-10-20', '2018-10-21', '2018-10-22', '2018-10-23',
#                '2018-10-24', '2018-10-25', '2018-10-26', '2018-10-27',
#                '2018-10-28', '2018-10-29', '2018-10-30', '2018-10-31'],
#               dtype='datetime64[ns]', name='date', freq='D')

# %% [markdown]
# Generate the values for the wite noise process representing Nina's commute in August and September.

# %%
# your code here
commute = [np.random.normal(loc=25, scale=4, size=len(dates))]
commute
# Out:
# [array([22.24448523, 28.2105218 , 26.08956416, 21.12329401, 28.48787249,
#         19.21456223, 22.85407494, 25.79168207, 19.53744074, 20.22222247,
#         25.06373817, 24.67982615, 23.99678915, 22.73942842, 20.58931224,
#         21.87087024, 37.16674483, 22.49567512, 31.02360365, 22.65065565,
#         30.46341166, 29.9281795 , 26.80355693, 22.43436073, 19.48961587,
#         28.86298539, 19.86398616, 19.9017116 , 31.09136705, 30.84752972,
#         25.15062385, 24.0152112 , 22.34280971, 26.40534215, 23.06387427,
#         18.94765096, 21.94587805, 25.99681284, 18.64076557, 21.08189631,
#         25.49104652, 31.75716838, 25.71099946, 25.12802408, 32.73286226,
#         20.75162115, 22.0694836 , 28.37096557, 29.30695995, 26.83076215,
#         14.52202671, 27.95618537, 27.67000423, 25.18561054, 27.66431039,
#         30.63179394, 25.20459675, 21.25610056, 17.64356277, 25.25511491,
#         22.14412761, 22.75246135, 20.4701246 , 26.09716401, 27.94364844,
#         26.737275  , 20.51983558, 28.55637844, 26.25802778, 15.04798214,
#         27.38363444, 16.85655185, 20.44687339, 29.23056915, 27.61107416,
#         22.42213259, 21.46615164, 26.38276949, 17.81269016, 26.64283848,
#         23.8327062 , 27.93659059, 24.49801734, 20.64593034, 25.8089237 ,
#         23.6006624 , 19.31489241, 20.34564666, 20.97329485, 25.20008704,
#         28.06172054, 24.88594049])]

# %% [markdown]
# Create a time series with the dates and the commute times.

# %%
# your code here
ts = pd.Series(data=commute[0], name='commute', index=dates)
df = pd.DataFrame(ts)

# %% [markdown]
# Visualize the time series and set appropriate axis labels.

# %%
# your code here
fig = plt.figure(figsize=(12,6))
plt.plot(df)
plt.xlabel('Date')
plt.ylabel('Commute Time (min)')
plt.show();

# %% [markdown]
# Print Nina's shortest and longest commute.

# %%
print(f'Max commute: {df.max()}')
print(f'Min commute: {df.min()}')
# Out:
# Max commute: commute    37.166745
# dtype: float64
# Min commute: commute    14.522027
# dtype: float64

# %% [markdown]
# Look at the distribution of commute times.

# %%
# your code here
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000016BCBB53DA0>]],
#       dtype=object)

# %% [markdown]
# Compute the standard deviation and the mean of the commute series. The fact that the mean and standard error are constant over time is crucial!

# %%
print(f'Standard Dev.: {df.commute.std()}')
print(f'Mean: {df.commute.mean()}')
# Out:
# Standard Dev.: 4.147899325404224
# Mean: 24.37343321110402

# %% [markdown]
# Now, let's look at the mean and standard error for August and October respectively.

# %%
aug_std = df.commute['2018-08'].std()
aug_mean = df.commute['2018-08'].mean()
print(f'August Mean: {aug_mean}')
print(f'August StD: {aug_std}')
# Out:
# August Mean: 24.86740942621537
# August StD: 4.478206654218108

# %%
oct_std = df.commute['2018-10'].std()
oct_mean = df.commute['2018-10'].mean()
print(f'Oct. Mean: {oct_mean}')
print(f'Oct. StD: {oct_std}')
# Out:
# Oct. Mean: 23.733632104934685
# Oct. StD: 3.76991643402267

# %% [markdown]
# Because you've generated this data, you know that the mean and constant will be the same over time. But comparing mean and standard deviation over time is useful practice for real data examples to check if a process is White Noise!

# %% [markdown]
# ## A Random Walk Model

# %% [markdown]
# Remember from the lecture that the Random Walk Model:

# %% [markdown]
# - Has no specified mean or variance
# - Has a strong dependence over time
#
# Mathematically, this can be written as:
#
# $$Y_t = Y_{t-1} + \epsilon_t$$
#
# Because today's value depends on yesterday's, you need a starting value when you start off your time series. In practice, this is what the first few time series values look like:
# $$ Y_0 = \text{some specified starting value}$$
# $$Y_1= Y_{0}+ \epsilon_1 $$
# $$Y_2= Y_{1}+ \epsilon_2 = Y_{0} + \epsilon_1 + \epsilon_2  $$
# $$Y_3= Y_{2}+ \epsilon_3 = Y_{0} + \epsilon_1 + \epsilon_2 + \epsilon_3 $$
# $$\ldots $$
#
# Keeping this in mind, let's create a random walk model:
# - starting from a value of 1000 USD of a share value upon a company's first IPO (initial public offering) in 2010 until end of November of the same year, generate a random walk model with a white noise error term, which has a standard error of 10.

# %%
# keep the random seed
np.random.seed(11)

# create a series with the specified dates
date = pd.date_range(start='2010-01-01', end='2010-11-30', name='date')

# %%
# Generate values using random walk model
value = 1000 # Initial value
values = []
for i in range(len(date)):
    values.append(value)
    value += np.random.normal(loc=0, scale=10) # update value with white noise term
    
print(len(date), len(values))
values
# Out:
# 334 334
# [1000,
#  995.9285087256108,
#  1008.2438735510486,
#  1011.7282174110934,
#  1006.8784794576053,
#  1011.2528719222079,
#  1007.6981875119109,
#  1013.1942043779763,
#  1014.7312551414541,
#  1025.820891121539,
#  1029.1752149693523,
#  1039.132369697453,
#  1039.0250881581765,
#  1046.1464004295087,
#  1044.6303773490572,
#  1051.0675391549162,
#  1053.3081367015122,
#  1052.0687386082125,
#  1047.873951969602,
#  1045.136744158693,
#  1049.8724628817454,
#  1026.9546150755823,
#  1039.3617917958693,
#  1015.687596734794,
#  1013.7909624979582,
#  1010.4957608653423,
#  1017.8899003725056,
#  1020.2476226440205,
#  1019.8157481610717,
#  1020.6547858279866,
#  1030.1172598336886,
#  1053.5278175389758,
#  1057.2984787184687,
#  1036.7051149488946,
#  1032.513034461023,
#  1036.7103688701416,
#  1069.857192385801,
#  1062.2029612172187,
#  1058.4821732562423,
#  1064.0743240887384,
#  1067.3071208240283,
#  1054.068492087089,
#  1063.5395763155507,
#  1050.3788807709466,
#  1047.7132919542735,
#  1060.9609039914842,
#  1047.7728642179059,
#  1044.3289701812735,
#  1061.0301087882494,
#  1058.4242025810563,
#  1047.9375685475302,
#  1042.1159857025773,
#  1050.4806406553885,
#  1034.7894496971721,
#  1028.4546464502034,
#  1013.8652129599271,
#  1002.2804443761274,
#  1015.1531060304485,
#  1014.3085542005457,
#  1009.9101158521845,
#  1014.1622398390653,
#  1007.0044793057151,
#  994.9455821517944,
#  1006.4156059942418,
#  1015.1961935416132,
#  1006.7121142868361,
#  1013.7557938863798,
#  1028.3574758935372,
#  1033.266985506486,
#  1038.2685965117955,
#  1025.8246236947768,
#  1024.475686736757,
#  1005.7220553721332,
#  1016.8724811841033,
#  1015.125078597403,
#  1028.3832676514924,
#  1020.6018558642184,
#  1029.367200333933,
#  1013.4302598469613,
#  1009.3388215228015,
#  1014.8044478037655,
#  1018.3614647213615,
#  1017.7487838975438,
#  1001.1704608239716,
#  1014.4525690758609,
#  1021.0740867485806,
#  1032.5212747060482,
#  1043.8375259032753,
#  1040.033051073748,
#  1043.9602285758494,
#  1070.5887643030153,
#  1062.1338077783346,
#  1066.2178746429793,
#  1060.5509525909347,
#  1078.168473942942,
#  1079.900710336572,
#  1069.3922124944218,
#  1063.2682925522647,
#  1049.0360957196565,
#  1025.9968214706519,
#  998.577515700339,
#  991.197966641774,
#  979.7413776092595,
#  981.2172108768923,
#  972.8259820282166,
#  975.0629225512301,
#  992.9437790777088,
#  981.0072040551337,
#  968.7122912229572,
#  978.6240584620762,
#  1002.3206819969475,
#  993.4433209159372,
#  976.3075466002016,
#  973.3251116226775,
#  969.1846173869858,
#  976.3396860516622,
#  965.5462624355446,
#  962.842592329179,
#  959.6488261643386,
#  943.6269462241643,
#  927.671174175658,
#  932.1449870905745,
#  937.635059099517,
#  929.5226773239531,
#  945.3313426541379,
#  954.7621919348181,
#  959.4195031293373,
#  965.5594563757974,
#  969.0598299772294,
#  976.3398501530984,
#  985.0672484572457,
#  985.7168164617784,
#  964.8314232791485,
#  963.1317101196317,
#  954.6059719197156,
#  942.46343052714,
#  948.4626797850349,
#  930.2793787046803,
#  938.6558433861476,
#  932.0768193758818,
#  919.5081952485607,
#  910.5694181613281,
#  934.2520026611936,
#  949.1575662175546,
#  946.1863514862944,
#  956.9611896582539,
#  975.0020997295065,
#  966.0280464432012,
#  963.0138738658508,
#  972.288720101963,
#  976.2844032826407,
#  972.39648105778,
#  988.8908377979157,
#  993.9906535155156,
#  1001.977384141644,
#  1026.2924234233121,
#  1031.2070842917062,
#  1058.136346506302,
#  1061.1795524776855,
#  1059.459843013948,
#  1060.702830678,
#  1069.5427387149705,
#  1076.1657868446027,
#  1079.8939288555719,
#  1064.646919299575,
#  1053.4470140969295,
#  1050.6418030570806,
#  1057.9904952129755,
#  1072.6680315894598,
#  1048.037312829759,
#  1046.4054465360093,
#  1041.5953939109856,
#  1040.345725636893,
#  1042.3579713991771,
#  1033.4924185847453,
#  1019.8104997160308,
#  1030.0066480695152,
#  1037.5406464676248,
#  1033.1159725604523,
#  1031.7141943416498,
#  1024.4760382895377,
#  1009.9051294270845,
#  1016.3688378830726,
#  1009.3716126296889,
#  997.7404879699931,
#  991.4087575279004,
#  1007.9835545165943,
#  1012.3343627915001,
#  1014.5640021904795,
#  1015.3134755697857,
#  1023.9481472616612,
#  1031.2532805118271,
#  1017.7296106564642,
#  1015.0824508228654,
#  1008.240206785207,
#  1010.2222571071343,
#  1009.3607034021737,
#  988.7075283194971,
#  1000.217763946587,
#  1002.6389103590777,
#  984.650809773004,
#  996.0584725552936,
#  997.0325239629458,
#  1001.5598763172467,
#  1001.5492734084074,
#  1002.8672482938479,
#  997.3573557538707,
#  979.9840230977487,
#  973.2747692719046,
#  974.7041867337044,
#  974.6682011836034,
#  980.8681836061972,
#  979.4294068501925,
#  956.0330122720505,
#  963.004980341841,
#  954.2207798956581,
#  939.9691037035112,
#  936.1214688500918,
#  921.6065764280736,
#  924.6552469084372,
#  914.5885195721854,
#  933.7126440937409,
#  930.4934870381371,
#  924.1338610258258,
#  916.7676245505768,
#  894.0476489913543,
#  884.4642733174594,
#  876.0066429804422,
#  871.8992932148255,
#  848.5435737667583,
#  848.2227886931367,
#  860.6189388386462,
#  855.5454888725535,
#  854.3138451393969,
#  857.9848609856531,
#  849.1720800017246,
#  844.0631953067815,
#  853.1571723390067,
#  854.5021931303071,
#  841.4393150108139,
#  822.7323851504094,
#  845.5068804700514,
#  849.5577070893537,
#  832.9438617498288,
#  834.0945728097724,
#  840.5923725595121,
#  841.4263527695543,
#  821.966030665872,
#  840.0861385226704,
#  845.8874465865215,
#  843.6138088470998,
#  850.3079641212844,
#  847.7890625855152,
#  844.1635763669917,
#  853.0380769975204,
#  832.6881041290635,
#  842.7310532966449,
#  846.6507830460921,
#  854.2721728433512,
#  863.4794684609782,
#  879.2629010346434,
#  893.9125759475187,
#  902.9107145503212,
#  898.9953911341203,
#  906.0603648938417,
#  901.2558580397049,
#  891.6198549634156,
#  896.3894299270764,
#  900.1868715340053,
#  912.485350750085,
#  890.8806752575989,
#  897.1772429679772,
#  904.2379670537272,
#  905.6349294752042,
#  920.9854711398717,
#  912.3751690189339,
#  916.1121468839409,
#  912.6379736313755,
#  912.817456328572,
#  903.2928245398394,
#  902.2251065389088,
#  909.4300499341166,
#  911.0148935964936,
#  914.8983579204272,
#  907.4805470383278,
#  924.0020669920909,
#  917.2995268301852,
#  917.888888955686,
#  924.2607444450241,
#  922.80826873574,
#  930.9087652459357,
#  933.2807211378056,
#  950.9996522233097,
#  957.0051250347037,
#  961.4598849290235,
#  953.6732732445291,
#  958.7825758511552,
#  969.3869624850588,
#  974.0079641530457,
#  964.9609451508325,
#  959.7997512906041,
#  957.8209756465236,
#  958.3863768684605,
#  944.700296602746,
#  964.0231666282494,
#  963.3450842890585,
#  964.8191299531555,
#  960.6586876026143,
#  960.5301907899328,
#  980.2482154903759,
#  970.9283450070106,
#  965.939216885722,
#  955.7132014226054,
#  950.382582291856,
#  966.0851972028947,
#  959.9387183211794,
#  955.5311223224094,
#  937.4515056966013,
#  934.0056928296234,
#  936.492662058749,
#  931.7472621795059,
#  927.9161970953832,
#  936.1771081334447,
#  941.6976149894327,
#  940.8505275319548,
#  933.1498680504861,
#  918.1619380282629,
#  935.3177453990152,
#  919.9176772645214,
#  926.6340936816188,
#  924.8503412479984,
#  917.664055864004,
#  926.7863848510461,
#  919.5346747067152]

# %%
# generate series object

ts = pd.Series(data=values, index=date, name='values')
ts_df = pd.DataFrame(ts)
ts_df.index
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                '2010-01-05', '2010-01-06', '2010-01-07', '2010-01-08',
#                '2010-01-09', '2010-01-10',
#                ...
#                '2010-11-21', '2010-11-22', '2010-11-23', '2010-11-24',
#                '2010-11-25', '2010-11-26', '2010-11-27', '2010-11-28',
#                '2010-11-29', '2010-11-30'],
#               dtype='datetime64[ns]', name='date', length=334, freq='D')

# %% [markdown]
# Visualize the time series with correct axis labels

# %%
# your code here
plt.figure(figsize=(12,6))
plt.plot(ts_df)
plt.xlabel('Date')
plt.ylabel('Share Value')
plt.show();

# %% [markdown]
# You can see how this very much looks like the exchange rate series you looked at in the lecture!

# %% [markdown]
# ## Random Walk with a Drift
#
# Repeat the above, but include a drift parameter $c$ of 8 now!

# %%
# keep the random seed
# Generate values using random walk model plus drift
value_d = 1000 # Initial value
c = 8 # drift term
values_d = []
for i in range(len(date)):
    values_d.append(value_d)
    value_d += np.random.normal(loc=0, scale=10) + c # update value with white noise term plus drift

# %%
# your code here
ts = pd.Series(data=values, index=date, name='values')
ts_df = pd.DataFrame(ts)
plt.figure(figsize=(12,6))
plt.plot(ts_df)
plt.xlabel('Date')
plt.ylabel('Share Value')
plt.show();

# %% [markdown]
# Note that there is a very strong drift here!

# %% [markdown]
# ## Differencing in a Random Walk model

# %% [markdown]
# One important property of the Random Walk model is that a differenced random walk returns a white noise. This is a result of the mathematical formula:
#
# $$Y_t = Y_{t-1} + \epsilon_t$$
# which is equivalent to
# $$Y_t - Y_{t-1} = \epsilon_t$$
#
# and we know that $\epsilon_t$ is a mean-zero white noise process!

# %% [markdown]
# Plot the differenced time series for the shares time series (no drift).

# %%
# your code here
ts_diff = ts.diff()

# %%
plt.figure(figsize=(12,6))
plt.plot(ts_diff)
plt.xlabel('Date')
plt.ylabel('Share Value')
plt.show();

# %% [markdown]
# This does look a lot like a white noise series!

# %% [markdown]
# Plot the differenced time series for the shares time series (with a drift).

# %%
# your code here
ts_ddiff = pd.Series(data=values_d, index=date, name='values_d').diff()
plt.figure(figsize=(12,6))
plt.plot(ts_ddiff)
plt.xlabel('Date')
plt.ylabel('Share Value')
plt.show();

# %% [markdown]
# This is also a white noise series, but what can you tell about the mean?

# %% [markdown]
# The mean is equal to the drift $c$, so 8 for this example!

# %% [markdown]
# ## Summary
#
# Great, you now know how a Random Walk and Moving Average model work!
